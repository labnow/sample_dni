# %%
import sqlite3
import pandas as pd
import numpy as np

month = '07'
conn = sqlite3.connect('audi.sqlite')
cur = conn.cursor()
query_sql = 'SELECT * FROM travel WHERE strftime("%m", date)=?'
data = cur.execute(query_sql, (month, )).fetchall()
table_header = [item[0] for item in cur.description]
conn.close()

df = pd.DataFrame(data, columns=table_header)
# df.dtypes
df.to_xml('1.xml')

# %%
import sqlite3

conn = sqlite3.connect('audi.sqlite')
cur = conn.cursor()
myQuery = 'SELECT * FROM effort ORDER BY id DESC LIMIT 2'
result = cur.execute(myQuery).fetchall()
result
# Out:
# [(620, 2, '2021-09-09', 'dalao', '14:22', '14:21', 8.0, 0.0, 'jj', 'kk'),
#  (619,
#   -1,
#   '2021-07-23',
#   '孙少鹏',
#   '8:49:00',
#   '18:07:00',
#   8.0,
#   0.0,
#   'Bosch/sgh',
#   '')]

# %%
pivot_tabele = pd.pivot_table(df, values='price', index='engineerName', columns='type', aggfunc=np.sum, fill_value=0, margins=True, margins_name='Total')
import lxml
pivot_tabele.to_xml('a.xml')
pivot_tabele.to_excel('isitok.xlsx')
pivot_tabele.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1199/3153239465.py in <module>
#       1 pivot_tabele = pd.pivot_table(df, values='price', index='engineerName', columns='type', aggfunc=np.sum, fill_value=0, margins=True, margins_name='Total')
#       2 import lxml
# ----> 3 pivot_tabele.to_xml('a.xml')
#       4 pivot_tabele.to_excel('isitok.xlsx')
#       5 pivot_tabele.head()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in to_xml(self, path_or_buffer, index, root_name, row_name, na_rep, attr_cols, elem_cols, namespaces, prefix, encoding, xml_declaration, pretty_print, parser, stylesheet, compression, storage_options)
#    2984         )
#    2985
# -> 2986         return xml_formatter.write_output()
#    2987
#    2988     # ----------------------------------------------------------------------
#
# ~/.local/lib/python3.8/site-packages/pandas/io/formats/xml.py in write_output(self)
#     263
#     264     def write_output(self) -> str | None:
# --> 265         xml_doc = self.build_tree()
#     266
#     267         out_str: str | None
#
# ~/.local/lib/python3.8/site-packages/pandas/io/formats/xml.py in build_tree(self)
#     483             if not self.attr_cols and not self.elem_cols:
#     484                 self.elem_cols = list(self.d.keys())
# --> 485                 self.build_elems()
#     486
#     487             else:
#
# ~/.local/lib/python3.8/site-packages/pandas/io/formats/xml.py in build_elems(self)
#     573                     else str(self.d[col])
#     574                 )
# --> 575                 SubElement(self.elem_row, elem_name).text = val
#     576             except KeyError:
#     577                 raise KeyError(f"no valid column, {col}")
#
# src/lxml/etree.pyx in lxml.etree.SubElement()
#
# src/lxml/apihelpers.pxi in lxml.etree._makeSubElement()
#
# src/lxml/apihelpers.pxi in lxml.etree._tagValidOrRaise()
#
# ValueError: Invalid tag name '1'

# %%
from openpyxl import Workbook, load_workbook

wb = load_workbook('tmp.xlsx')
for i in range(1,5):
    sheet_name = str(i) + 'abc'
    ws = wb.copy_worksheet(wb['Sheet'])
    # wb.create_sheet(sheet_name)
    ws.title = sheet_name
    ws.cell(row=2, column=1, value=sheet_name)

wb.save('tmp.xlsx')

# %%
import zipfile
import os
from flask import send_file

@app.route('/download_all')
def download_all():
    zipf = zipfile.ZipFile('Name.zip','w', zipfile.ZIP_DEFLATED)
    for root,dirs, files in os.walk('output/'):
        for file in files:
            zipf.write('output/'+file)
    zipf.close()
    return send_file('Name.zip',
            mimetype = 'zip',
            attachment_filename= 'Name.zip',
            as_attachment = True)
# Out:
# [('赵文龙', '07'),
#  ('王鹏龙', '07'),
#  ('胡乃涛', '07'),
#  ('杨雪盈', '07'),
#  ('白军艳', '07'),
#  ('钟伟', '07'),
#  ('吴鹏', '07'),
#  ('丁秀菊', '07'),
#  ('蒋赫敏', '07'),
#  ('闫淑娟', '07'),
#  ('戴芳', '07'),
#  ('崔拯', '07'),
#  ('李敏芳', '07'),
#  ('徐大炎', '07'),
#  ('孙少鹏', '07'),
#  ('唐野', '06'),
#  ('唐野', '07'),
#  ('唐野', '08')]

# %%
uninteresting_columns = [item for item in table_header if item not in interested_columns]
uninteresting_columns
# Out:
# ['id', 'engineerName']

# %%
# df = df.drop(columns=uninteresting_columns)
# add Total row
# pd.to_numeric(df['workingHours'],downcast='float')
df['overtime'] = df['overtime'].astype('float')
df.dtypes
# Out:
# package          object
# date             object
# startTime        object
# endTime          object
# workingHours     object
# overtime        float64
# location         object
# worklog          object
# dtype: object

# %%
df.loc['total'] = df.select_dtypes(np.number).sum()
df
# Out:
#          package        date startTime   endTime workingHours  overtime  \
# 0      CADA/CAPA  2021-07-01   8:42:00  18:22:00          8.0       0.0
# 1      CADA/CAPA  2021-07-02   8:58:00  18:28:00          8.0       0.0
# 2      CADA/CAPA  2021-07-05   8:45:00  18:16:00          8.0       0.0
# 3      CADA/CAPA  2021-07-06   8:57:00  18:10:00          8.0       0.0
# 4      CADA/CAPA  2021-07-07   8:53:00  18:10:00          8.0       0.0
# 5      CADA/CAPA  2021-07-08   8:51:00  18:10:00          8.0       0.0
# 6      CADA/CAPA  2021-07-09   8:35:00  18:10:00          8.0       0.0
# 7      CADA/CAPA  2021-07-12   8:41:00  18:02:00          8.0       0.0
# 8      CADA/CAPA  2021-07-13   8:57:00  18:14:00          8.0       0.0
# 9      CADA/CAPA  2021-07-14   8:53:00  18:20:00          8.0       0.0
# 10     CADA/CAPA  2021-07-15   8:43:00  18:30:00          8.0       0.0
# 11     CADA/CAPA  2021-07-16   8:55:00  18:17:00          8.0       0.0
# 12     CADA/CAPA  2021-07-19   8:53:00  18:16:00          8.0       0.0
# 13     CADA/CAPA  2021-07-20   8:43:00  18:11:00          8.0       0.0
# 14     CADA/CAPA  2021-07-21   8:52:00  18:23:00          8.0       0.0
# 15     CADA/CAPA  2021-07-22   8:52:00  18:31:00          8.0       0.0
# 16     CADA/CAPA  2021-07-23   8:46:00  18:37:00          8.0       0.0
# 17     CADA/CAPA  2021-07-26   8:55:00  18:10:00          8.0       0.0
# 18     CADA/CAPA  2021-07-27   8:46:00  18:01:00          8.0       0.0
# 19     CADA/CAPA  2021-07-28   8:43:00  18:09:00          8.0       0.0
# 20     CADA/CAPA  2021-07-29   8:43:00  18:16:00          8.0       0.0
# 21     CADA/CAPA  2021-07-30   8:55:00  18:23:00          8.0       0.0
# total        NaN         NaN       NaN       NaN          NaN       0.0
#
#         location                                            worklog
# 0      Bosch/sgh
# 1      Bosch/sgh
# 2         MA/ACB       1. CADA LAH reading.\r\n2. CAPA LAH reading.
# 3         MA/ACB
# 4         MA/ACB
# 5         MA/ACB
# 6         MA/sgh
# 7         MA/ACB  1. CADA LAH reading.\r\n2. Bench analysis and ...
# 8         MA/ACB
# 9         MA/ACB
# 10        MA/ACB
# 11        MA/ACB
# 12        MA/ACB  1. CADA LAH reading.\r\n2. Bench analysis and ...
# 13        MA/ACB
# 14        MA/ACB
# 15        MA/ACB
# 16     Bosch/sgh
# 17     Bosch/sgh  1. Teams internal support on PPE/CADA/CAPA and...
# 18     Bosch/sgh
# 19     Bosch/sgh
# 20     Bosch/sgh
# 21     Bosch/sgh
# total        NaN                                                NaN
